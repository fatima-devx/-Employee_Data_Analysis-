# %% [markdown]
# <a href="https://colab.research.google.com/github/fatima-devx/-Employee_Data_Analysis-/blob/main/%E2%80%8FEmployee_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("employees_data.csv")
df.head()
# Out:
#   Employee_ID    Name  Age Department  Salary  Performance_Score
# 0        E001   Ahmed   28      Sales    6500                 88
# 1        E002    Sara   31         HR    7200                 92
# 2        E003    Mona   26  Marketing    6000                 85
# 3        E004  Khalid   35      Sales    7800                 95
# 4        E005   Noura   29         IT    9000                 98

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        10 non-null     object
#  1   Name               10 non-null     object
#  2   Age                10 non-null     int64
#  3   Department         10 non-null     object
#  4   Salary             10 non-null     int64
#  5   Performance_Score  10 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 612.0+ bytes

# %%
df.describe()
# Out:
#              Age        Salary  Performance_Score
# count  10.000000     10.000000          10.000000
# mean   31.100000   7950.000000          90.100000
# std     4.175324   1766.509427           4.433459
# min    26.000000   6000.000000          84.000000
# 25%    28.250000   6575.000000          87.250000
# 50%    30.500000   7500.000000          89.500000
# 75%    32.750000   8875.000000          92.750000
# max    40.000000  11000.000000          98.000000

# %%
department_count = df["Department"].value_counts()

print(department_count)
# Out:
# Department
# Sales        2
# HR           2
# Marketing    2
# IT           2
# Finance      2
# Name: count, dtype: int64

# %%
avg_salary = df.groupby("Department")["Salary"].mean()

print(avg_salary)
# Out:
# Department
# Finance      10750.0
# HR            7000.0
# IT            8750.0
# Marketing     6100.0
# Sales         7150.0
# Name: Salary, dtype: float64

# %%
avg_performance = df.groupby("Department")["Performance_Score"].mean()

print(avg_performance)
# Out:
# Department
# Finance      91.0
# HR           89.5
# IT           94.0
# Marketing    84.5
# Sales        91.5
# Name: Performance_Score, dtype: float64

# %%
print("Highest Salary:", df["Salary"].max())
print("Lowest Salary:", df["Salary"].min())
# Out:
# Highest Salary: 11000
# Lowest Salary: 6000

# %%
import matplotlib.pyplot as plt

department_count.plot(kind="bar")

plt.title("Number of Employees by Department")
plt.xlabel("Department")
plt.ylabel("Number of Employees")

plt.show()

# %%
avg_salary.plot(kind="bar")

plt.title("Average Salary by Department")
plt.xlabel("Department")
plt.ylabel("Average Salary")

plt.show()

# %%
print("Employee Data Analysis Completed")
print("Average Age:", df["Age"].mean())
print("Highest Salary:", df["Salary"].max())
print("Lowest Salary:", df["Salary"].min())
# Out:
# Employee Data Analysis Completed
# Average Age: 31.1
# Highest Salary: 11000
# Lowest Salary: 6000
